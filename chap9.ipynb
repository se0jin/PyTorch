# %%
import nltk
nltk.download()
text = nltk.word_tokenize("Is it possible distinguishing cats and dogs")
text
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# ['Is', 'it', 'possible', 'distinguishing', 'cats', 'and', 'dogs']

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\516-08\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
nltk.download('punkt')
string1 = "my favorite subject is math"
string2 = "my favorite subject is math, english, economic and computer science"
nltk.word_tokenize(string1)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\516-08\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['my', 'favorite', 'subject', 'is', 'math']

# %%
nltk.word_tokenize(string2)
# Out:
# ['my',
#  'favorite',
#  'subject',
#  'is',
#  'math',
#  ',',
#  'english',
#  ',',
#  'economic',
#  'and',
#  'computer',
#  'science']

# %%
pip install konlpy
pip install -U gensim
# Out:
#   Cell In[5], line 1
#     pip install konlpy
#         ^
# SyntaxError: invalid syntax

# %%
from konlpy.tag import Komoran
komoran = Komoran()
print(komoran.morphs('딥러닝이 쉽나요? 어렵나요?')
# Out:
#   Cell In[6], line 3
#     print(komoran.morphs('딥러닝이 쉽나요? 어렵나요?')
#                                            ^
# SyntaxError: incomplete input

# %%
print(komoran.pos('소파 위에 있는 것이 고양이인가요? 강아지인가요?'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(komoran.pos('소파 위에 있는 것이 고양이인가요? 강아지인가요?'))
#
# NameError: name 'komoran' is not defined

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\user\\chap09\\data\\class2.csv')
df

# %%
df.isnull().sum()

# %%
df.isnull().sum() / len(df)
